# %% [markdown]
# #### Anyhow, change the user permission of serial port like '/dev/ttyACM0' before run this notebook/python

# %% [markdown]
# Here is the guidance
# ````
# $ sudo su
# # usermod -aG dialout your_username
# # exit
# $ newgrp dialout
# ````

# %% [markdown]
# #### If you still encounter unavaiable port problem, specify the serial port to microbit with the following code by changing this cell from Markdown to Code.
#
# PORT = '/dev/ttyACM0'
# with open('microbit/config.py', 'w') as fw: fw.write(f"PORT='{PORT}'")

# %%
# !pip install pyserial

# %%
import microbit 
for i in range(10):
    for i in range(len(microbit.Image.ALL_ARROWS)):
        microbit.display.show(microbit.Image.ALL_ARROWS[i])
        microbit.sleep(100)

# %% [markdown]
# ### Preview of the Result
# <br>
# <div> <img src="data:image/gif;base64,..." alt="Red dot" /> </div>
