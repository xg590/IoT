# %%
# !pip3 install bluezero # Install if you haven't

# %% [markdown]
# ### MakeCode <br>
# <div> <img src="data:image/png;base64,..." alt="Red dot" /> </div>

# %%
from bluezero import microbit
ubit = microbit.Microbit(adapter_addr='iMac bluetooth chip addr',
                         device_addr='microbit bluetooth addr',
                         accelerometer_service=True,
                         magnetometer_service=True, 
                         button_service=False,
                         led_service=True, 
                         pin_service=False,
                         temperature_service=True) # Every Service must be specified

# %%
ubit.connect()

# %% [markdown]
# ### Pattern Before ubit.connect()
# <div> <img src="data:image/png;base64,..." alt="Red dot" /> </div>

# %% [markdown]
# ### Pattern After ubit.connect()
# <div> <img src="data:image/png;base64,..." alt="Red dot" /> </div>

# %%
ubit.text = 'ddd'

# %% [markdown]
# ### Pattern After ubit.connect()
# <div> <img src="data:image/png;base64,..." alt="Red dot" /> </div>

# %%
ubit.accelerometer
# Out:
# [0.016, 0.824, -0.648]

# %%
ubit.magnetometer
# Out:
# [-4.964, 17.7, -3.15]

# %%
ubit.calibrate() # You should never use ubit.calibrate and ubit.bearing, 
                 # otherwise you have to remove, re-pair, connect the Micro:bit

# %%
ubit.disconnect()

# %% [markdown]
# ### Pattern After ubit.disconnect()
# <div> <img src="data:image/png;base64,..." alt="Red dot" /> </div>
